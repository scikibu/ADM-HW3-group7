# %%
import pandas as pd

# %%
#create the dataframe with selected doc_i
l = [0, 1, 2] #list of numner that we should have after search engine! Now I put just the number of doc we have
d = {}
table = pd.DataFrame(columns=['Title', 'Description', 'City', 'Url']) #empty dataframe to be filled
for i in l:
    d[i] = pd.read_csv('doc_{}.tsv'.format(i), sep='\t', encoding = 'ISO-8859-1', header = None) #trasform doc_i to dataframe
    df = d[i]
    df = df.replace({r'\s+$': '', r'^\s+': ''}, regex=True).replace(r'\\n',  ' ', regex=True) #remove newline \n
    df = df.replace({r'\s+$': '', r'^\s+': ''}, regex=True).replace(r'[^\x00-\x7f]',  ' ', regex=True) #remove hex notation
    #remove dollar sign beacuse it create a lot of troubles  
    df = df.replace({r'\s+$': '', r'^\s+': ''}, regex=True).replace(r'\$',  ' ', regex=True) 
    df = df[[7, 4, 2, 8]] #keep just needed columns
    df.columns = ['Title', 'Description', 'City', 'Url'] #rename columns
    table = table.append(df) #append the corrected dataframe
    

#improve dataframe display:

#remove index
table.reset_index(drop = True, inplace = True)

#make url clickable
table = table.style.hide_index()
def make_clickable(val):
    return '<a target="_blank" href="{}">{}</a>'.format(val, val)
table = table.format({'Url': make_clickable})

#change fontsize, allign the text and edit dimension of cells
table = table.set_table_styles({'props': [('font-size', '10pt')]}).set_properties(**{'font-size': '10.5pt'})
d = dict(selector="th", props=[('text-align', 'center')])
table = table.set_properties(**{'width':'20em', 'height':'10em', 'text-align':'center'}).set_table_styles([d])

table #print table
# Out:
# <style  type="text/css" >
#     #T_9c7b3cb4_e83a_11e8_afe1_c064b56bba13 th {
#           text-align: center;
#     }    #T_9c7b3cb4_e83a_11e8_afe1_c064b56bba13row0_col0 {
#             font-size:  10.5pt;
#             width:  20em;
#             height:  10em;
#             text-align:  center;
#         }    #T_9c7b3cb4_e83a_11e8_afe1_c064b56bba13row0_col1 {
#             font-size:  10.5pt;
#             width:  20em;
#             height:  10em;
#             text-align:  center;
#         }    #T_9c7b3cb4_e83a_11e8_afe1_c064b56bba13row0_col2 {
#             font-size:  10.5pt;
#             width:  20em;
#             height:  10em;
#             text-align:  center;
#         }    #T_9c7b3cb4_e83a_11e8_afe1_c064b56bba13row0_col3 {
#             font-size:  10.5pt;
#             width:  20em;
#             height:  10em;
#             text-align:  center;
#         }    #T_9c7b3cb4_e83a_11e8_afe1_c064b56bba13row1_col0 {
#             font-size:  10.5pt;
#             width:  20em;
#             height:  10em;
#             text-align:  center;
#         }    #T_9c7b3cb4_e83a_11e8_afe1_c064b56bba13row1_col1 {
#             font-size:  10.5pt;
#             width:  20em;
#             height:  10em;
#             text-align:  center;
#         }    #T_9c7b3cb4_e83a_11e8_afe1_c064b56bba13row1_col2 {
#             font-size:  10.5pt;
#             width:  20em;
#             height:  10em;
#             text-align:  center;
#         }    #T_9c7b3cb4_e83a_11e8_afe1_c064b56bba13row1_col3 {
#             font-size:  10.5pt;
#             width:  20em;
#             height:  10em;
#             text-align:  center;
#         }    #T_9c7b3cb4_e83a_11e8_afe1_c064b56bba13row2_col0 {
#             font-size:  10.5pt;
#             width:  20em;
#             height:  10em;
#             text-align:  center;
#         }    #T_9c7b3cb4_e83a_11e8_afe1_c064b56bba13row2_col1 {
#             font-size:  10.5pt;
#             width:  20em;
#             height:  10em;
#             text-align:  center;
#         }    #T_9c7b3cb4_e83a_11e8_afe1_c064b56bba13row2_col2 {
#             font-size:  10.5pt;
#             width:  20em;
#             height:  10em;
#             text-align:  center;
#         }    #T_9c7b3cb4_e83a_11e8_afe1_c064b56bba13row2_col3 {
#             font-size:  10.5pt;
#             width:  20em;
#             height:  10em;
#             text-align:  center;
#         }</style>
# <table id="T_9c7b3cb4_e83a_11e8_afe1_c064b56bba13" >
# <thead>    <tr>
#         <th class="col_heading level0 col0" >Title</th>
#         <th class="col_heading level0 col1" >Description</th>
#         <th class="col_heading level0 col2" >City</th>
#         <th class="col_heading level0 col3" >Url</th>
#     </tr></thead>
# <tbody>    <tr>
#         <td id="T_9c7b3cb4_e83a_11e8_afe1_c064b56bba13row0_col0" class="data row0 col0" >2 Private rooms/bathroom 10min from IAH airport</td>
#         <td id="T_9c7b3cb4_e83a_11e8_afe1_c064b56bba13row0_col1" class="data row0 col1" >Welcome to stay in private room with queen bed and detached private bathroom on the second floor. Another private bedroom with sofa bed is available for additional guests. 10  for an additional guest. 10min from IAH airport Airport pick-up/drop off is available for  10/trip.</td>
#         <td id="T_9c7b3cb4_e83a_11e8_afe1_c064b56bba13row0_col2" class="data row0 col2" >Humble</td>
#         <td id="T_9c7b3cb4_e83a_11e8_afe1_c064b56bba13row0_col3" class="data row0 col3" ><a target="_blank" href="https://www.airbnb.com/rooms/18520444?location=Cleveland%2C%20TX">https://www.airbnb.com/rooms/18520444?location=Cleveland%2C%20TX</a></td>
#     </tr>    <tr>
#         <td id="T_9c7b3cb4_e83a_11e8_afe1_c064b56bba13row1_col0" class="data row1 col0" >Unique Location! Alamo Heights - Designer Inspired</td>
#         <td id="T_9c7b3cb4_e83a_11e8_afe1_c064b56bba13row1_col1" class="data row1 col1" >Stylish, fully remodeled home in upscale NW   Alamo Heights Area.   Amazing location - House conveniently located in quiet street, with beautiful seasoned trees, prestigious neighborhood and very close to the airport, 281, 410 loop and down-town area.   Featuring an open floor plan, original hardwood floors, 3 bedrooms, 3 FULL bathrooms + an independent garden-TV room which can sleep 2 more  European inspired kitchen and  top of the line  decor. Driveway can park 4 cars.</td>
#         <td id="T_9c7b3cb4_e83a_11e8_afe1_c064b56bba13row1_col2" class="data row1 col2" >San Antonio</td>
#         <td id="T_9c7b3cb4_e83a_11e8_afe1_c064b56bba13row1_col3" class="data row1 col3" ><a target="_blank" href="https://www.airbnb.com/rooms/17481455?location=Cibolo%2C%20TX">https://www.airbnb.com/rooms/17481455?location=Cibolo%2C%20TX</a></td>
#     </tr>    <tr>
#         <td id="T_9c7b3cb4_e83a_11e8_afe1_c064b56bba13row2_col0" class="data row2 col0" >River house near the city</td>
#         <td id="T_9c7b3cb4_e83a_11e8_afe1_c064b56bba13row2_col1" class="data row2 col1" >'River house on island close to the city'  A well maintained river house off the San Jacinto river with extra room for temporary visitors.</td>
#         <td id="T_9c7b3cb4_e83a_11e8_afe1_c064b56bba13row2_col2" class="data row2 col2" >Houston</td>
#         <td id="T_9c7b3cb4_e83a_11e8_afe1_c064b56bba13row2_col3" class="data row2 col3" ><a target="_blank" href="https://www.airbnb.com/rooms/16926307?location=Beach%20City%2C%20TX">https://www.airbnb.com/rooms/16926307?location=Beach%20City%2C%20TX</a></td>
#     </tr></tbody>
# </table>
